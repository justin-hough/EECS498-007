# %% [markdown]
# # EECS 498-007/598-005 Assignment 2-1: Linear Classifiers

# %% [markdown]
# ## Setup Code
# Before getting started, we need to run some boilerplate code to set up our environment, same as Assignment 1. You'll need to rerun this setup code each time you start the notebook.
#
# First, run this cell load the autoreload extension. This allows us to edit .py source files, and re-import them into the notebook for a seamless editing and debugging experience.

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### Google Colab Setup
# Next we need to run a few commands to set up our environment on Google Colab. If you are running this notebook on a local machine you can skip this section.
#
# Run the following cell to mount your Google Drive. Follow the link, sign in to your Google account (the same account you used to store this notebook!) and copy the authorization code into the text box that appears below.

# %%
#from google.colab import drive
#drive.mount('/content/drive')

# %% [markdown]
# Now recall the path in your Google Drive where you uploaded this notebook, fill it in below. If everything is working correctly then running the folowing cell should print the filenames from the assignment:
#
# ```
# ['two_layer_net.ipynb', 'eecs598', 'two_layer_net.py', 'linear_classifier.py', 'linear_classifier.ipynb', 'challenge_problem.ipynb']
# ```

# %%
import os

# TODO: Fill in the Google Drive path where you uploaded the assignment
# Example: If you create a 2020FA folder and put all the files under A2 folder, then '2020FA/A2'
# GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = '2020FA/A2'
#GOOGLE_DRIVE_PATH_AFTER_MYDRIVE = None
#GOOGLE_DRIVE_PATH = os.path.join('drive', 'My Drive', GOOGLE_DRIVE_PATH_AFTER_MYDRIVE)
GOOGLE_DRIVE_PATH = os.path.abspath("") # TODO Only use this if running the notebook locally
#print(os.listdir(GOOGLE_DRIVE_PATH))

# %% [markdown]
# Once you have successfully mounted your Google Drive and located the path to this assignment, run th following cell to allow us to import from the `.py` files of this assignment. If it works correctly, it should print the message:
#
# ```
# Hello from linear_classifier.py!
# ```
#
# as well as the last edit time for the file `linear_classifier.py`.

# %%
import sys
sys.path.append(GOOGLE_DRIVE_PATH)
"""
import time, os
os.environ["TZ"] = "US/Eastern"
time.tzset()

from linear_classifier import hello_linear_classifier
hello_linear_classifier()

linear_classifier_path = os.path.join(GOOGLE_DRIVE_PATH, 'linear_classifier.py')
linear_classifier_edit_time = time.ctime(os.path.getmtime(linear_classifier_path))
print('linear_classifier.py last edited on %s' % linear_classifier_edit_time)
"""
# Out:
# '\nimport time, os\nos.environ["TZ"] = "US/Eastern"\ntime.tzset()\n\nfrom linear_classifier import hello_linear_classifier\nhello_linear_classifier()\n\nlinear_classifier_path = os.path.join(GOOGLE_DRIVE_PATH, \'linear_classifier.py\')\nlinear_classifier_edit_time = time.ctime(os.path.getmtime(linear_classifier_path))\nprint(\'linear_classifier.py last edited on %s\' % linear_classifier_edit_time)\n'

# %% [markdown]
# # Data preprocessing

# %% [markdown]
# ## Setup code
# Run some setup code for this notebook: Import some useful packages and increase the default figure size.

# %%
import eecs598
import torch
import torchvision
import matplotlib.pyplot as plt
import statistics
import random
import time
import math
# %matplotlib inline


plt.rcParams['figure.figsize'] = (10.0, 8.0)
plt.rcParams['font.size'] = 16

# %% [markdown]
# Starting in this assignment, we will use the GPU to accelerate our computation. Run this cell to make sure you are using a GPU.

# %%
if torch.cuda.is_available:
  print('Good to go!')
else:
  print('Please set GPU via Edit -> Notebook Settings.')
# Out:
# Good to go!

# %% [markdown]
# ## Load the CIFAR-10 dataset
# Then, we will first load the CIFAR-10 dataset, same as knn. The utility function `eecs598.data.preprocess_cifar10()` returns the entire CIFAR-10 dataset as a set of six **Torch tensors**:
#
# - `X_train` contains all training images (real numbers in the range $[0, 1]$)
# - `y_train` contains all training labels (integers in the range $[0, 9]$)
# - `X_val` contains all validation images
# - `y_val` contains all validation labels
# - `X_test` contains all test images
# - `y_test` contains all test labels
#
# In this notebook we will use the **bias trick**: By adding an extra constant feature of ones to each image, we avoid the need to keep track of a bias vector; the bias will be encoded as the part of the weight matrix that interacts with the constant ones in the input.
#
# In the `two_layer_net.ipynb` notebook that follows this one, we will not use the bias trick.
#
# We can learn more about the `eecs598.data.preprocess_cifar10` function by invoking the `help` command:

# %%
import eecs598
help(eecs598.data.preprocess_cifar10)
# Out:
# Help on function preprocess_cifar10 in module eecs598.data:
#
# preprocess_cifar10(cuda=True, show_examples=True, bias_trick=False, flatten=True, validation_ratio=0.2, dtype=torch.float32)
#     Returns a preprocessed version of the CIFAR10 dataset, automatically
#     downloading if necessary. We perform the following steps:
#
#     (0) [Optional] Visualize some images from the dataset
#     (1) Normalize the data by subtracting the mean
#     (2) Reshape each image of shape (3, 32, 32) into a vector of shape (3072,)
#     (3) [Optional] Bias trick: add an extra dimension of ones to the data
#     (4) Carve out a validation set from the training set
#
#     Inputs:
#     - cuda: If true, move the entire dataset to the GPU
#     - validation_ratio: Float in the range (0, 1) giving the fraction of the train
#       set to reserve for validation
#     - bias_trick: Boolean telling whether or not to apply the bias trick
#     - show_examples: Boolean telling whether or not to visualize data samples
#     - dtype: Optional, data type of the input image X
#
#     Returns a dictionary with the following keys:
#     - 'X_train': `dtype` tensor of shape (N_train, D) giving training images
#     - 'X_val': `dtype` tensor of shape (N_val, D) giving val images
#     - 'X_test': `dtype` tensor of shape (N_test, D) giving test images
#     - 'y_train': int64 tensor of shape (N_train,) giving training labels
#     - 'y_val': int64 tensor of shape (N_val,) giving val labels
#     - 'y_test': int64 tensor of shape (N_test,) giving test labels
#
#     N_train, N_val, and N_test are the number of examples in the train, val, and
#     test sets respectively. The precise values of N_train and N_val are determined
#     by the input parameter validation_ratio. D is the dimension of the image data;
#     if bias_trick is False, then D = 32 * 32 * 3 = 3072;
#     if bias_trick is True then D = 1 + 32 * 32 * 3 = 3073.

# %% [markdown]
# We can now run the `eecs598.data.preprocess` function to get our data:

# %%
# Invoke the above function to get our data. 
import eecs598

eecs598.reset_seed(0)
data_dict = eecs598.data.preprocess_cifar10(bias_trick=True, cuda=True, dtype=torch.float64)
print('Train data shape: ', data_dict['X_train'].shape)
print('Train labels shape: ', data_dict['y_train'].shape)
print('Validation data shape: ', data_dict['X_val'].shape)
print('Validation labels shape: ', data_dict['y_val'].shape)
print('Test data shape: ', data_dict['X_test'].shape)
print('Test labels shape: ', data_dict['y_test'].shape)
# Out:
# Train data shape:  torch.Size([40000, 3073])
# Train labels shape:  torch.Size([40000])
# Validation data shape:  torch.Size([10000, 3073])
# Validation labels shape:  torch.Size([10000])
# Test data shape:  torch.Size([10000, 3073])
# Test labels shape:  torch.Size([10000])

# %% [markdown]
# # SVM Classifier
#
# In this section, you will:
#
# - implement a fully-vectorized **loss function** for the SVM
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** using numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights
#
# In Assignment 2, you SHOULD NOT use ".to()" or ".cuda()" in each implementation block. Otherwise, your implementation would gives you an error in Autograder end.

# %% [markdown]
# First, we will test the naive version of svm loss in `linear_classifier.py`. Let's first try the naive implementation of the loss we provided for you. You will get 9.000197. (Note: we've provided the `loss` part of the `svm_loss_naive` function, so you don't need to re-implement in `svm_loss_naive`. However, if your loss value doesn't match, then please report this to [Piazza](https://piazza.com/class/kxtai72amx34p0))

# %%
import eecs598
from linear_classifier import svm_loss_naive

eecs598.reset_seed(0)
# generate a random SVM weight tensor of small numbers
W = torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device) * 0.0001 

loss, _grad_ = svm_loss_naive(W, data_dict['X_val'], data_dict['y_val'], 0.000005)
print('loss: %f' % (loss, ))
# Out:
# loss: 9.000888

# %% [markdown]
# The `_grad_` returned from the function above is right now all zero. Derive and implement the gradient for the SVM cost function and implement it inline inside the function `svm_loss_naive`, by filing out the TODO blocks. You will find it helpful to interweave your new code inside the existing function.
#
# To check that you have implemented the gradient correctly, we will use **numeric gradient checking**: we will use a finite differences approach to numerically estimate the gradient of the forward pass, and compare this numeric gradient to the analytic gradient that you implemented.
#
# We have provided a function `eecs598.grad.grad_check_sparse` to help with numeric gradient checking. You can learn more about this function using the `help` command:

# %%
import eecs598
help(eecs598.grad.grad_check_sparse)
# Out:
# Help on function grad_check_sparse in module eecs598.grad:
#
# grad_check_sparse(f, x, analytic_grad, num_checks=10, h=1e-07)
#     Utility function to perform numeric gradient checking. We use the centered
#     difference formula to compute a numeric derivative:
#
#     f'(x) =~ (f(x + h) - f(x - h)) / (2h)
#
#     Rather than computing a full numeric gradient, we sparsely sample a few
#     dimensions along which to compute numeric derivatives.
#
#     Inputs:
#     - f: A function that inputs a torch tensor and returns a torch scalar
#     - x: A torch tensor of the point at which to evaluate the numeric gradient
#     - analytic_grad: A torch tensor giving the analytic gradient of f at x
#     - num_checks: The number of dimensions along which to check
#     - h: Step size for computing numeric derivatives

# %% [markdown]
# Now run the following to perform numeric gradient checking on the gradients of your SVM loss. You should see relative errors less than `1e-5`.

# %%
import eecs598
from linear_classifier import svm_loss_naive

# Once you've implemented the gradient, recompute it with the code below
# and gradient check it with the function we provided for you

# Use a random W and a minibatch of data from the val set for gradient checking
# For numeric gradient checking it is a good idea to use 64-bit floating point
# numbers for increased numeric precision; however when actually training models
# we usually use 32-bit floating point numbers for increased speed.
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
batch_size = 64
X_batch = data_dict['X_val'][:batch_size]
y_batch = data_dict['y_val'][:batch_size]

# Compute the loss and its gradient at W.
# YOUR_TURN: implement the gradient part of 'svm_loss_naive' function in "linear_classifier.py"
_, grad = svm_loss_naive(W, X_batch, y_batch, reg=0.0)

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should
# match almost exactly along all dimensions.
f = lambda w: svm_loss_naive(w, X_batch, y_batch, reg=0.0)[0]
grad_numerical = eecs598.grad.grad_check_sparse(f, W, grad)
# Out:
# numerical: 0.031599 analytic: 0.031599, relative error: 3.139148e-07
# numerical: 0.111444 analytic: 0.111444, relative error: 9.893848e-10
# numerical: 0.011204 analytic: 0.011204, relative error: 1.003052e-06
# numerical: -0.046128 analytic: -0.046128, relative error: 1.470228e-08
# numerical: 0.071948 analytic: 0.071948, relative error: 1.000117e-07
# numerical: 0.025688 analytic: 0.025688, relative error: 1.051337e-06
# numerical: 0.185388 analytic: 0.185388, relative error: 7.039118e-09
# numerical: -0.021740 analytic: -0.021740, relative error: 3.369463e-07
# numerical: -0.159613 analytic: -0.159613, relative error: 6.416943e-08
# numerical: 0.092690 analytic: 0.092690, relative error: 1.748534e-07

# %% [markdown]
# Let's do the gradient check once again with regularization turned on. (You didn't forget the regularization gradient, did you?)
#
# You should see relative errors less than `1e-5`.

# %%
import eecs598
from linear_classifier import svm_loss_naive

# Use a minibatch of data from the val set for gradient checking
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
batch_size = 64
X_batch = data_dict['X_val'][:batch_size]
y_batch = data_dict['y_val'][:batch_size]

# Compute the loss and its gradient at W.
# YOUR_TURN: check your 'svm_loss_naive' implementation with different 'reg'
_, grad = svm_loss_naive(W, X_batch, y_batch, reg=1e3) 

# Numerically compute the gradient along several randomly chosen dimensions, and
# compare them with your analytically computed gradient. The numbers should
# match almost exactly along all dimensions.
f = lambda w: svm_loss_naive(w, X_batch, y_batch, reg=1e3)[0]
grad_numerical = eecs598.grad.grad_check_sparse(f, W, grad)
# Out:
# numerical: 0.124849 analytic: 0.124849, relative error: 6.251581e-08
# numerical: 0.168915 analytic: 0.168915, relative error: 5.957873e-09
# numerical: 0.148752 analytic: 0.148752, relative error: 8.733009e-08
# numerical: -0.024936 analytic: -0.024936, relative error: 1.133872e-07
# numerical: -0.008570 analytic: -0.008570, relative error: 7.174549e-07
# numerical: -0.103155 analytic: -0.103155, relative error: 2.498757e-07
# numerical: -0.335573 analytic: -0.335573, relative error: 4.472387e-09
# numerical: -0.222176 analytic: -0.222176, relative error: 4.264915e-08
# numerical: 0.681163 analytic: 0.681163, relative error: 1.235571e-08
# numerical: -0.004090 analytic: -0.004089, relative error: 4.327973e-06

# %% [markdown]
# Now, let's implement vectorized version of SVM: `svm_loss_vectorized`. It should compute the same inputs and outputs as the naive version before, but it should involve **no explicit loops**.
#
# Let's first check the speed and performance bewteen the non-vectorized and the vectorized version. You should see a 15-120x speedup. PyTorch does some extra setup the first time you run CUDA code, so **you may need to run this cell more than once to see the desired speedup**.
#
# (Note: It may have some difference, but should be less than 1e-6)

# %%
import eecs598
from linear_classifier import svm_loss_naive, svm_loss_vectorized

# Use random weights and a minibatch of val data for gradient checking
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]
reg = 0.000005

# Run and time the naive version
torch.cuda.synchronize()
tic = time.time()
loss_naive, grad_naive = svm_loss_naive(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_naive = 1000.0 * (toc - tic)
print('Naive loss: %e computed in %.2fms' % (loss_naive, ms_naive))

# Run and time the vectorized version
torch.cuda.synchronize()
tic = time.time()
# YOUR_TURN: implement the loss part of 'svm_loss_vectorized' function in "linear_classifier.py"
loss_vec, _ = svm_loss_vectorized(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_vec = 1000.0 * (toc - tic)
print('Vectorized loss: %e computed in %.2fms' % (loss_vec, ms_vec))

# The losses should match but your vectorized implementation should be much faster.
print('Difference: %.2e' % (loss_naive - loss_vec))
print('Speedup: %.2fX' % (ms_naive / ms_vec))
# Out:
# Naive loss: 9.002394e+00 computed in 519.37ms
# Vectorized loss: 9.002394e+00 computed in 8.14ms
# Difference: 1.53e-09
# Speedup: 63.78X

# %% [markdown]
# Then, let's compute the gradient of the loss function. We can check the difference of gradient as well. (The error should be less than 1e-6)
#
# Now implement a vectorized version of the gradient computation in `svm_loss_vectorize` above. Run the cell below to compare the gradient of your naive and vectorized implementations. The difference between the gradients should be less than `1e-6`, and the vectorized version should run 15-120x faster.

# %%
# The naive implementation and the vectorized implementation should match, but
# the vectorized version should still be much faster.

import eecs598
from linear_classifier import svm_loss_naive, svm_loss_vectorized

# Use random weights and a minibatch of val data for gradient checking
eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]
reg = 0.000005

# Run and time the naive version
torch.cuda.synchronize()
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_batch, y_batch, 0.000005)
torch.cuda.synchronize()
toc = time.time()
ms_naive = 1000.0 * (toc - tic)
print('Naive loss and gradient: computed in %.2fms' % ms_naive)

# Run and time the vectorized version
torch.cuda.synchronize()
tic = time.time()
# YOUR_TURN: implement the gradient part of 'svm_loss_vectorized' function in "linear_classifier.py"
_, grad_vec = svm_loss_vectorized(W, X_batch, y_batch, 0.000005)
torch.cuda.synchronize()
toc = time.time()
ms_vec = 1000.0 * (toc - tic)
print('Vectorized loss and gradient: computed in %.2fms' % ms_vec)

# The loss is a single number, so it is easy to compare the values computed
# by the two implementations. The gradient on the other hand is a tensor, so
# we use the Frobenius norm to compare them.
grad_difference = torch.norm(grad_naive - grad_vec, p='fro')
print('Gradient difference: %.2e' % grad_difference)
print('Speedup: %.2fX' % (ms_naive / ms_vec))
# Out:
# Naive loss and gradient: computed in 533.02ms
# Vectorized loss and gradient: computed in 3.12ms
# Gradient difference: 1.74e-07
# Speedup: 170.75X

# %% [markdown]
# Now that we have an efficient vectorized implementation of the SVM loss and its gradient, we can implement a training pipeline for linear classifiers.
#
# Please complete the implementation of `train_linear_classifier` in `linear_classifer.py`.

# %% [markdown]
# Once you have implemented the training function, run the following cell to train a linear classifier using some default hyperparameters:
#
# (You should see a final loss close to 9.0, and your training loop should run in about two seconds)

# %%
import eecs598
from linear_classifier import svm_loss_vectorized, train_linear_classifier

# fix random seed before we perform this operation
eecs598.reset_seed(0)

torch.cuda.synchronize()
tic = time.time()

# YOUR_TURN: Implement how to construct the batch, 
#            and how to update the weight in 'train_linear_classifier'
W, loss_hist = train_linear_classifier(svm_loss_vectorized, None, 
                                       data_dict['X_train'], 
                                       data_dict['y_train'], 
                                       learning_rate=3e-13, reg=2.5e4,
                                       num_iters=1500, verbose=True)

torch.cuda.synchronize()
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 9.000019
# iteration 100 / 1500: loss 8.999997
# iteration 200 / 1500: loss 9.000013
# iteration 300 / 1500: loss 9.000002
# iteration 400 / 1500: loss 9.000015
# iteration 500 / 1500: loss 9.000009
# iteration 600 / 1500: loss 9.000010
# iteration 700 / 1500: loss 9.000009
# iteration 800 / 1500: loss 9.000012
# iteration 900 / 1500: loss 9.000013
# iteration 1000 / 1500: loss 9.000011
# iteration 1100 / 1500: loss 9.000031
# iteration 1200 / 1500: loss 9.000029
# iteration 1300 / 1500: loss 9.000012
# iteration 1400 / 1500: loss 9.000020
# That took 2.565600s

# %% [markdown]
# A useful debugging strategy is to plot the loss as a function of iteration number. In this case it seems our hyperparameters are not good, since the training loss is not decreasing very fast.

# %%
plt.plot(loss_hist, 'o')
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# Then, let's move on to the prediction stage. We can evaluate the performance our trained model on both the training and validation set. You should see validation accuracy less than 20%.

# %%
import eecs598
from linear_classifier import predict_linear_classifier

# fix random seed before we perform this operation
eecs598.reset_seed(0)

# evaluate the performance on both the training and validation set
# YOUR_TURN: Implement how to make a prediction with the trained weight 
#            in 'predict_linear_classifier'
y_train_pred = predict_linear_classifier(W, data_dict['X_train'])
train_acc = 100.0 * (data_dict['y_train'] == y_train_pred).double().mean().item()
print('Training accuracy: %.2f%%' % train_acc)

y_val_pred = predict_linear_classifier(W, data_dict['X_val'])
val_acc = 100.0 * (data_dict['y_val'] == y_val_pred).double().mean().item()
print('Validation accuracy: %.2f%%' % val_acc)
# Out:
# Training accuracy: 8.74%
# Validation accuracy: 8.40%

# %% [markdown]
# Unfortunately, the performance of our initial model is quite bad. To find a better hyperparamters, we first modulized the functions that we've implemented as LinearSVM.

# %% [markdown]
# Now, please use the validation set to tune hyperparameters (regularization strength and learning rate). You should experiment with different ranges for the learning rates and regularization strengths.
#
# To get full credit for the assignment your best model found through cross-validation should achieve an accuracy of at least 37% on the validation set.
#
# (Our best model got over 38.1% -- did you beat us?)

# %%
import os
import eecs598
from linear_classifier import LinearSVM, svm_get_search_params, test_one_param_set

# YOUR_TURN: find the best learning_rates and regularization_strengths combination
#            in 'svm_get_search_params'
learning_rates, regularization_strengths = svm_get_search_params()
num_models = len(learning_rates) * len(regularization_strengths)

####
# It is okay to comment out the following conditions when you are working on svm_get_search_params.
# But, please do not forget to reset back to the original setting once you are done.
# if num_models > 25:
#   raise Exception("Please do not test/submit more than 25 items at once")
# elif num_models < 5:
#   raise Exception("Please present at least 5 parameter sets in your final ipynb")
####


i = 0
# results is dictionary mapping tuples of the form
# (learning_rate, regularization_strength) to tuples of the form
# (train_acc, val_acc). 
results = {}
best_val = -1.0   # The highest validation accuracy that we have seen so far.
best_svm_model = None # The LinearSVM object that achieved the highest validation rate.
num_iters = 2000 # number of iterations

for lr in learning_rates:
  for reg in regularization_strengths:
    i += 1
    print('Training SVM %d / %d with learning_rate=%e and reg=%e'
          % (i, num_models, lr, reg))
    
    eecs598.reset_seed(0)
    # YOUR_TURN: implement a function that gives the trained model with 
    #            train/validation accuracies in 'test_one_param_set'
    #            (note: this function will be used in Softmax Classifier section as well)
    cand_svm_model, cand_train_acc, cand_val_acc = test_one_param_set(LinearSVM(), data_dict, lr, reg, num_iters)

    if cand_val_acc > best_val:
      best_val = cand_val_acc
      best_svm_model = cand_svm_model # save the svm
    results[(lr, reg)] = (cand_train_acc, cand_val_acc)


# Print out results.
for lr, reg in sorted(results):
  train_acc, val_acc = results[(lr, reg)]
  print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
         lr, reg, train_acc, val_acc))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)

# save the best model
path = os.path.join(GOOGLE_DRIVE_PATH, 'svm_best_model.pt')
best_svm_model.save(path)
# Out:
# Training SVM 1 / 240 with learning_rate=1.778279e-03 and reg=0.000000e+00
# Training SVM 2 / 240 with learning_rate=1.778279e-03 and reg=1.000000e-10
# Training SVM 3 / 240 with learning_rate=1.778279e-03 and reg=5.179475e-10
# Training SVM 4 / 240 with learning_rate=1.778279e-03 and reg=2.682696e-09
# Training SVM 5 / 240 with learning_rate=1.778279e-03 and reg=1.389495e-08
# Training SVM 6 / 240 with learning_rate=1.778279e-03 and reg=7.196856e-08
# Training SVM 7 / 240 with learning_rate=1.778279e-03 and reg=3.727594e-07
# Training SVM 8 / 240 with learning_rate=1.778279e-03 and reg=1.930698e-06
# Training SVM 9 / 240 with learning_rate=1.778279e-03 and reg=1.000000e-05
# Training SVM 10 / 240 with learning_rate=1.778279e-03 and reg=5.179475e-05
# Training SVM 11 / 240 with learning_rate=1.778279e-03 and reg=2.682696e-04
# Training SVM 12 / 240 with learning_rate=1.778279e-03 and reg=1.389495e-03
# Training SVM 13 / 240 with learning_rate=1.778279e-03 and reg=7.196857e-03
# Training SVM 14 / 240 with learning_rate=1.778279e-03 and reg=3.727594e-02
# Training SVM 15 / 240 with learning_rate=1.778279e-03 and reg=1.930698e-01
# Training SVM 16 / 240 with learning_rate=1.778279e-03 and reg=1.000000e+00
# Training SVM 17 / 240 with learning_rate=2.275846e-03 and reg=0.000000e+00
# Training SVM 18 / 240 with learning_rate=2.275846e-03 and reg=1.000000e-10
# Training SVM 19 / 240 with learning_rate=2.275846e-03 and reg=5.179475e-10
# Training SVM 20 / 240 with learning_rate=2.275846e-03 and reg=2.682696e-09
# Training SVM 21 / 240 with learning_rate=2.275846e-03 and reg=1.389495e-08
# Training SVM 22 / 240 with learning_rate=2.275846e-03 and reg=7.196856e-08
# Training SVM 23 / 240 with learning_rate=2.275846e-03 and reg=3.727594e-07
# Training SVM 24 / 240 with learning_rate=2.275846e-03 and reg=1.930698e-06
# Training SVM 25 / 240 with learning_rate=2.275846e-03 and reg=1.000000e-05
# Training SVM 26 / 240 with learning_rate=2.275846e-03 and reg=5.179475e-05
# Training SVM 27 / 240 with learning_rate=2.275846e-03 and reg=2.682696e-04
# Training SVM 28 / 240 with learning_rate=2.275846e-03 and reg=1.389495e-03
# Training SVM 29 / 240 with learning_rate=2.275846e-03 and reg=7.196857e-03
# Training SVM 30 / 240 with learning_rate=2.275846e-03 and reg=3.727594e-02
# Training SVM 31 / 240 with learning_rate=2.275846e-03 and reg=1.930698e-01
# Training SVM 32 / 240 with learning_rate=2.275846e-03 and reg=1.000000e+00
# Training SVM 33 / 240 with learning_rate=2.912633e-03 and reg=0.000000e+00
# Training SVM 34 / 240 with learning_rate=2.912633e-03 and reg=1.000000e-10
# Training SVM 35 / 240 with learning_rate=2.912633e-03 and reg=5.179475e-10
# Training SVM 36 / 240 with learning_rate=2.912633e-03 and reg=2.682696e-09
# Training SVM 37 / 240 with learning_rate=2.912633e-03 and reg=1.389495e-08
# Training SVM 38 / 240 with learning_rate=2.912633e-03 and reg=7.196856e-08
# Training SVM 39 / 240 with learning_rate=2.912633e-03 and reg=3.727594e-07
# Training SVM 40 / 240 with learning_rate=2.912633e-03 and reg=1.930698e-06
# Training SVM 41 / 240 with learning_rate=2.912633e-03 and reg=1.000000e-05
# Training SVM 42 / 240 with learning_rate=2.912633e-03 and reg=5.179475e-05
# Training SVM 43 / 240 with learning_rate=2.912633e-03 and reg=2.682696e-04
# Training SVM 44 / 240 with learning_rate=2.912633e-03 and reg=1.389495e-03
# Training SVM 45 / 240 with learning_rate=2.912633e-03 and reg=7.196857e-03
# Training SVM 46 / 240 with learning_rate=2.912633e-03 and reg=3.727594e-02
# Training SVM 47 / 240 with learning_rate=2.912633e-03 and reg=1.930698e-01
# Training SVM 48 / 240 with learning_rate=2.912633e-03 and reg=1.000000e+00
# Training SVM 49 / 240 with learning_rate=3.727594e-03 and reg=0.000000e+00
# Training SVM 50 / 240 with learning_rate=3.727594e-03 and reg=1.000000e-10
# Training SVM 51 / 240 with learning_rate=3.727594e-03 and reg=5.179475e-10
# Training SVM 52 / 240 with learning_rate=3.727594e-03 and reg=2.682696e-09
# Training SVM 53 / 240 with learning_rate=3.727594e-03 and reg=1.389495e-08
# Training SVM 54 / 240 with learning_rate=3.727594e-03 and reg=7.196856e-08
# Training SVM 55 / 240 with learning_rate=3.727594e-03 and reg=3.727594e-07
# Training SVM 56 / 240 with learning_rate=3.727594e-03 and reg=1.930698e-06
# Training SVM 57 / 240 with learning_rate=3.727594e-03 and reg=1.000000e-05
# Training SVM 58 / 240 with learning_rate=3.727594e-03 and reg=5.179475e-05
# Training SVM 59 / 240 with learning_rate=3.727594e-03 and reg=2.682696e-04
# Training SVM 60 / 240 with learning_rate=3.727594e-03 and reg=1.389495e-03
# Training SVM 61 / 240 with learning_rate=3.727594e-03 and reg=7.196857e-03
# Training SVM 62 / 240 with learning_rate=3.727594e-03 and reg=3.727594e-02
# Training SVM 63 / 240 with learning_rate=3.727594e-03 and reg=1.930698e-01
# Training SVM 64 / 240 with learning_rate=3.727594e-03 and reg=1.000000e+00
# Training SVM 65 / 240 with learning_rate=4.770583e-03 and reg=0.000000e+00
# Training SVM 66 / 240 with learning_rate=4.770583e-03 and reg=1.000000e-10
# Training SVM 67 / 240 with learning_rate=4.770583e-03 and reg=5.179475e-10
# Training SVM 68 / 240 with learning_rate=4.770583e-03 and reg=2.682696e-09
# Training SVM 69 / 240 with learning_rate=4.770583e-03 and reg=1.389495e-08
# Training SVM 70 / 240 with learning_rate=4.770583e-03 and reg=7.196856e-08
# Training SVM 71 / 240 with learning_rate=4.770583e-03 and reg=3.727594e-07
# Training SVM 72 / 240 with learning_rate=4.770583e-03 and reg=1.930698e-06
# Training SVM 73 / 240 with learning_rate=4.770583e-03 and reg=1.000000e-05
# Training SVM 74 / 240 with learning_rate=4.770583e-03 and reg=5.179475e-05
# Training SVM 75 / 240 with learning_rate=4.770583e-03 and reg=2.682696e-04
# Training SVM 76 / 240 with learning_rate=4.770583e-03 and reg=1.389495e-03
# Training SVM 77 / 240 with learning_rate=4.770583e-03 and reg=7.196857e-03
# Training SVM 78 / 240 with learning_rate=4.770583e-03 and reg=3.727594e-02
# Training SVM 79 / 240 with learning_rate=4.770583e-03 and reg=1.930698e-01
# Training SVM 80 / 240 with learning_rate=4.770583e-03 and reg=1.000000e+00
# Training SVM 81 / 240 with learning_rate=6.105402e-03 and reg=0.000000e+00
# Training SVM 82 / 240 with learning_rate=6.105402e-03 and reg=1.000000e-10
# Training SVM 83 / 240 with learning_rate=6.105402e-03 and reg=5.179475e-10
# Training SVM 84 / 240 with learning_rate=6.105402e-03 and reg=2.682696e-09
# Training SVM 85 / 240 with learning_rate=6.105402e-03 and reg=1.389495e-08
# Training SVM 86 / 240 with learning_rate=6.105402e-03 and reg=7.196856e-08
# Training SVM 87 / 240 with learning_rate=6.105402e-03 and reg=3.727594e-07
# Training SVM 88 / 240 with learning_rate=6.105402e-03 and reg=1.930698e-06
# Training SVM 89 / 240 with learning_rate=6.105402e-03 and reg=1.000000e-05
# Training SVM 90 / 240 with learning_rate=6.105402e-03 and reg=5.179475e-05
# Training SVM 91 / 240 with learning_rate=6.105402e-03 and reg=2.682696e-04
# Training SVM 92 / 240 with learning_rate=6.105402e-03 and reg=1.389495e-03
# Training SVM 93 / 240 with learning_rate=6.105402e-03 and reg=7.196857e-03
# Training SVM 94 / 240 with learning_rate=6.105402e-03 and reg=3.727594e-02
# Training SVM 95 / 240 with learning_rate=6.105402e-03 and reg=1.930698e-01
# Training SVM 96 / 240 with learning_rate=6.105402e-03 and reg=1.000000e+00
# Training SVM 97 / 240 with learning_rate=7.813707e-03 and reg=0.000000e+00
# Training SVM 98 / 240 with learning_rate=7.813707e-03 and reg=1.000000e-10
# Training SVM 99 / 240 with learning_rate=7.813707e-03 and reg=5.179475e-10
# Training SVM 100 / 240 with learning_rate=7.813707e-03 and reg=2.682696e-09
# Training SVM 101 / 240 with learning_rate=7.813707e-03 and reg=1.389495e-08
# Training SVM 102 / 240 with learning_rate=7.813707e-03 and reg=7.196856e-08
# Training SVM 103 / 240 with learning_rate=7.813707e-03 and reg=3.727594e-07
# Training SVM 104 / 240 with learning_rate=7.813707e-03 and reg=1.930698e-06
# Training SVM 105 / 240 with learning_rate=7.813707e-03 and reg=1.000000e-05
# Training SVM 106 / 240 with learning_rate=7.813707e-03 and reg=5.179475e-05
# Training SVM 107 / 240 with learning_rate=7.813707e-03 and reg=2.682696e-04
# Training SVM 108 / 240 with learning_rate=7.813707e-03 and reg=1.389495e-03
# Training SVM 109 / 240 with learning_rate=7.813707e-03 and reg=7.196857e-03
# Training SVM 110 / 240 with learning_rate=7.813707e-03 and reg=3.727594e-02
# Training SVM 111 / 240 with learning_rate=7.813707e-03 and reg=1.930698e-01
# Training SVM 112 / 240 with learning_rate=7.813707e-03 and reg=1.000000e+00
# Training SVM 113 / 240 with learning_rate=1.000000e-02 and reg=0.000000e+00
# Training SVM 114 / 240 with learning_rate=1.000000e-02 and reg=1.000000e-10
# Training SVM 115 / 240 with learning_rate=1.000000e-02 and reg=5.179475e-10
# Training SVM 116 / 240 with learning_rate=1.000000e-02 and reg=2.682696e-09
# Training SVM 117 / 240 with learning_rate=1.000000e-02 and reg=1.389495e-08
# Training SVM 118 / 240 with learning_rate=1.000000e-02 and reg=7.196856e-08
# Training SVM 119 / 240 with learning_rate=1.000000e-02 and reg=3.727594e-07
# Training SVM 120 / 240 with learning_rate=1.000000e-02 and reg=1.930698e-06
# Training SVM 121 / 240 with learning_rate=1.000000e-02 and reg=1.000000e-05
# Training SVM 122 / 240 with learning_rate=1.000000e-02 and reg=5.179475e-05
# Training SVM 123 / 240 with learning_rate=1.000000e-02 and reg=2.682696e-04
# Training SVM 124 / 240 with learning_rate=1.000000e-02 and reg=1.389495e-03
# Training SVM 125 / 240 with learning_rate=1.000000e-02 and reg=7.196857e-03
# Training SVM 126 / 240 with learning_rate=1.000000e-02 and reg=3.727594e-02
# Training SVM 127 / 240 with learning_rate=1.000000e-02 and reg=1.930698e-01
# Training SVM 128 / 240 with learning_rate=1.000000e-02 and reg=1.000000e+00
# Training SVM 129 / 240 with learning_rate=1.279802e-02 and reg=0.000000e+00
# Training SVM 130 / 240 with learning_rate=1.279802e-02 and reg=1.000000e-10
# Training SVM 131 / 240 with learning_rate=1.279802e-02 and reg=5.179475e-10
# Training SVM 132 / 240 with learning_rate=1.279802e-02 and reg=2.682696e-09
# Training SVM 133 / 240 with learning_rate=1.279802e-02 and reg=1.389495e-08
# Training SVM 134 / 240 with learning_rate=1.279802e-02 and reg=7.196856e-08
# Training SVM 135 / 240 with learning_rate=1.279802e-02 and reg=3.727594e-07
# Training SVM 136 / 240 with learning_rate=1.279802e-02 and reg=1.930698e-06
# Training SVM 137 / 240 with learning_rate=1.279802e-02 and reg=1.000000e-05
# Training SVM 138 / 240 with learning_rate=1.279802e-02 and reg=5.179475e-05
# Training SVM 139 / 240 with learning_rate=1.279802e-02 and reg=2.682696e-04
# Training SVM 140 / 240 with learning_rate=1.279802e-02 and reg=1.389495e-03
# Training SVM 141 / 240 with learning_rate=1.279802e-02 and reg=7.196857e-03
# Training SVM 142 / 240 with learning_rate=1.279802e-02 and reg=3.727594e-02
# Training SVM 143 / 240 with learning_rate=1.279802e-02 and reg=1.930698e-01
# Training SVM 144 / 240 with learning_rate=1.279802e-02 and reg=1.000000e+00
# Training SVM 145 / 240 with learning_rate=1.637894e-02 and reg=0.000000e+00
# Training SVM 146 / 240 with learning_rate=1.637894e-02 and reg=1.000000e-10
# Training SVM 147 / 240 with learning_rate=1.637894e-02 and reg=5.179475e-10
# Training SVM 148 / 240 with learning_rate=1.637894e-02 and reg=2.682696e-09
# Training SVM 149 / 240 with learning_rate=1.637894e-02 and reg=1.389495e-08
# Training SVM 150 / 240 with learning_rate=1.637894e-02 and reg=7.196856e-08
# Training SVM 151 / 240 with learning_rate=1.637894e-02 and reg=3.727594e-07
# Training SVM 152 / 240 with learning_rate=1.637894e-02 and reg=1.930698e-06
# Training SVM 153 / 240 with learning_rate=1.637894e-02 and reg=1.000000e-05
# Training SVM 154 / 240 with learning_rate=1.637894e-02 and reg=5.179475e-05
# Training SVM 155 / 240 with learning_rate=1.637894e-02 and reg=2.682696e-04
# Training SVM 156 / 240 with learning_rate=1.637894e-02 and reg=1.389495e-03
# Training SVM 157 / 240 with learning_rate=1.637894e-02 and reg=7.196857e-03
# Training SVM 158 / 240 with learning_rate=1.637894e-02 and reg=3.727594e-02
# Training SVM 159 / 240 with learning_rate=1.637894e-02 and reg=1.930698e-01
# Training SVM 160 / 240 with learning_rate=1.637894e-02 and reg=1.000000e+00
# Training SVM 161 / 240 with learning_rate=2.096180e-02 and reg=0.000000e+00
# Training SVM 162 / 240 with learning_rate=2.096180e-02 and reg=1.000000e-10
# Training SVM 163 / 240 with learning_rate=2.096180e-02 and reg=5.179475e-10
# Training SVM 164 / 240 with learning_rate=2.096180e-02 and reg=2.682696e-09
# Training SVM 165 / 240 with learning_rate=2.096180e-02 and reg=1.389495e-08
# Training SVM 166 / 240 with learning_rate=2.096180e-02 and reg=7.196856e-08
# Training SVM 167 / 240 with learning_rate=2.096180e-02 and reg=3.727594e-07
# Training SVM 168 / 240 with learning_rate=2.096180e-02 and reg=1.930698e-06
# Training SVM 169 / 240 with learning_rate=2.096180e-02 and reg=1.000000e-05
# Training SVM 170 / 240 with learning_rate=2.096180e-02 and reg=5.179475e-05
# Training SVM 171 / 240 with learning_rate=2.096180e-02 and reg=2.682696e-04
# Training SVM 172 / 240 with learning_rate=2.096180e-02 and reg=1.389495e-03
# Training SVM 173 / 240 with learning_rate=2.096180e-02 and reg=7.196857e-03
# Training SVM 174 / 240 with learning_rate=2.096180e-02 and reg=3.727594e-02
# Training SVM 175 / 240 with learning_rate=2.096180e-02 and reg=1.930698e-01
# Training SVM 176 / 240 with learning_rate=2.096180e-02 and reg=1.000000e+00
# Training SVM 177 / 240 with learning_rate=2.682696e-02 and reg=0.000000e+00
# Training SVM 178 / 240 with learning_rate=2.682696e-02 and reg=1.000000e-10
# Training SVM 179 / 240 with learning_rate=2.682696e-02 and reg=5.179475e-10
# Training SVM 180 / 240 with learning_rate=2.682696e-02 and reg=2.682696e-09
# Training SVM 181 / 240 with learning_rate=2.682696e-02 and reg=1.389495e-08
# Training SVM 182 / 240 with learning_rate=2.682696e-02 and reg=7.196856e-08
# Training SVM 183 / 240 with learning_rate=2.682696e-02 and reg=3.727594e-07
# Training SVM 184 / 240 with learning_rate=2.682696e-02 and reg=1.930698e-06
# Training SVM 185 / 240 with learning_rate=2.682696e-02 and reg=1.000000e-05
# Training SVM 186 / 240 with learning_rate=2.682696e-02 and reg=5.179475e-05
# Training SVM 187 / 240 with learning_rate=2.682696e-02 and reg=2.682696e-04
# Training SVM 188 / 240 with learning_rate=2.682696e-02 and reg=1.389495e-03
# Training SVM 189 / 240 with learning_rate=2.682696e-02 and reg=7.196857e-03
# Training SVM 190 / 240 with learning_rate=2.682696e-02 and reg=3.727594e-02
# Training SVM 191 / 240 with learning_rate=2.682696e-02 and reg=1.930698e-01
# Training SVM 192 / 240 with learning_rate=2.682696e-02 and reg=1.000000e+00
# Training SVM 193 / 240 with learning_rate=3.433320e-02 and reg=0.000000e+00
# Training SVM 194 / 240 with learning_rate=3.433320e-02 and reg=1.000000e-10
# Training SVM 195 / 240 with learning_rate=3.433320e-02 and reg=5.179475e-10
# Training SVM 196 / 240 with learning_rate=3.433320e-02 and reg=2.682696e-09
# Training SVM 197 / 240 with learning_rate=3.433320e-02 and reg=1.389495e-08
# Training SVM 198 / 240 with learning_rate=3.433320e-02 and reg=7.196856e-08
# Training SVM 199 / 240 with learning_rate=3.433320e-02 and reg=3.727594e-07
# Training SVM 200 / 240 with learning_rate=3.433320e-02 and reg=1.930698e-06
# Training SVM 201 / 240 with learning_rate=3.433320e-02 and reg=1.000000e-05
# Training SVM 202 / 240 with learning_rate=3.433320e-02 and reg=5.179475e-05
# Training SVM 203 / 240 with learning_rate=3.433320e-02 and reg=2.682696e-04
# Training SVM 204 / 240 with learning_rate=3.433320e-02 and reg=1.389495e-03
# Training SVM 205 / 240 with learning_rate=3.433320e-02 and reg=7.196857e-03
# Training SVM 206 / 240 with learning_rate=3.433320e-02 and reg=3.727594e-02
# Training SVM 207 / 240 with learning_rate=3.433320e-02 and reg=1.930698e-01
# Training SVM 208 / 240 with learning_rate=3.433320e-02 and reg=1.000000e+00
# Training SVM 209 / 240 with learning_rate=4.393971e-02 and reg=0.000000e+00
# Training SVM 210 / 240 with learning_rate=4.393971e-02 and reg=1.000000e-10
# Training SVM 211 / 240 with learning_rate=4.393971e-02 and reg=5.179475e-10
# Training SVM 212 / 240 with learning_rate=4.393971e-02 and reg=2.682696e-09
# Training SVM 213 / 240 with learning_rate=4.393971e-02 and reg=1.389495e-08
# Training SVM 214 / 240 with learning_rate=4.393971e-02 and reg=7.196856e-08
# Training SVM 215 / 240 with learning_rate=4.393971e-02 and reg=3.727594e-07
# Training SVM 216 / 240 with learning_rate=4.393971e-02 and reg=1.930698e-06
# Training SVM 217 / 240 with learning_rate=4.393971e-02 and reg=1.000000e-05
# Training SVM 218 / 240 with learning_rate=4.393971e-02 and reg=5.179475e-05
# Training SVM 219 / 240 with learning_rate=4.393971e-02 and reg=2.682696e-04
# Training SVM 220 / 240 with learning_rate=4.393971e-02 and reg=1.389495e-03
# Training SVM 221 / 240 with learning_rate=4.393971e-02 and reg=7.196857e-03
# Training SVM 222 / 240 with learning_rate=4.393971e-02 and reg=3.727594e-02
# Training SVM 223 / 240 with learning_rate=4.393971e-02 and reg=1.930698e-01
# Training SVM 224 / 240 with learning_rate=4.393971e-02 and reg=1.000000e+00
# Training SVM 225 / 240 with learning_rate=5.623413e-02 and reg=0.000000e+00
# Training SVM 226 / 240 with learning_rate=5.623413e-02 and reg=1.000000e-10
# Training SVM 227 / 240 with learning_rate=5.623413e-02 and reg=5.179475e-10
# Training SVM 228 / 240 with learning_rate=5.623413e-02 and reg=2.682696e-09
# Training SVM 229 / 240 with learning_rate=5.623413e-02 and reg=1.389495e-08
# Training SVM 230 / 240 with learning_rate=5.623413e-02 and reg=7.196856e-08
# Training SVM 231 / 240 with learning_rate=5.623413e-02 and reg=3.727594e-07
# Training SVM 232 / 240 with learning_rate=5.623413e-02 and reg=1.930698e-06
# Training SVM 233 / 240 with learning_rate=5.623413e-02 and reg=1.000000e-05
# Training SVM 234 / 240 with learning_rate=5.623413e-02 and reg=5.179475e-05
# Training SVM 235 / 240 with learning_rate=5.623413e-02 and reg=2.682696e-04
# Training SVM 236 / 240 with learning_rate=5.623413e-02 and reg=1.389495e-03
# Training SVM 237 / 240 with learning_rate=5.623413e-02 and reg=7.196857e-03
# Training SVM 238 / 240 with learning_rate=5.623413e-02 and reg=3.727594e-02
# Training SVM 239 / 240 with learning_rate=5.623413e-02 and reg=1.930698e-01
# Training SVM 240 / 240 with learning_rate=5.623413e-02 and reg=1.000000e+00
# lr 1.778279e-03 reg 0.000000e+00 train accuracy: 39.785000 val accuracy: 38.520000
# lr 1.778279e-03 reg
-07

# %% [markdown]
# Let's perform another gradient check with regularization enabled. Again you should see relative errors less than `1e-5`.

# %%
import eecs598
from linear_classifier import softmax_loss_naive

eecs598.reset_seed(128)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
reg = 10.0

X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]

# YOUR_TURN: Complete the gradient compuation part of softmax_loss_naive 
_, grad = softmax_loss_naive(W, X_batch, y_batch, reg)

f = lambda w: softmax_loss_naive(w, X_batch, y_batch, reg)[0]
eecs598.grad.grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 0.004914 analytic: 0.004914, relative error: 2.907815e-08
# numerical: 0.005887 analytic: 0.005887, relative error: 8.060044e-07
# numerical: 0.006309 analytic: 0.006309, relative error: 1.166504e-08
# numerical: 0.001580 analytic: 0.001580, relative error: 1.087482e-06
# numerical: 0.005839 analytic: 0.005839, relative error: 8.457771e-07
# numerical: 0.006800 analytic: 0.006800, relative error: 6.637346e-07
# numerical: 0.011465 analytic: 0.011465, relative error: 2.593154e-07
# numerical: 0.002314 analytic: 0.002314, relative error: 4.575594e-07
# numerical: -0.016813 analytic: -0.016813, relative error: 9.876027e-08
# numerical: -0.006673 analytic: -0.006673, relative error: 3.461301e-07

# %% [markdown]
# Then, let's move on to the vectorized form: `softmax_loss_vectorized`.

# %% [markdown]
# Now that we have a naive implementation of the softmax loss function and its gradient, implement a vectorized version in softmax_loss_vectorized. The two versions should compute the same results, but the vectorized version should be much faster.
#
# The differences between the naive and vectorized losses and gradients should both be less than `1e-6`, and your vectorized implementation should be at least 20x faster than the naive implementation.

# %%
import eecs598
from linear_classifier import softmax_loss_naive, softmax_loss_vectorized

eecs598.reset_seed(0)
W = 0.0001 * torch.randn(3073, 10, dtype=data_dict['X_val'].dtype, device=data_dict['X_val'].device)
reg = 0.05

X_batch = data_dict['X_val'][:128]
y_batch = data_dict['y_val'][:128]

# Run and time the naive version
torch.cuda.synchronize()
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_naive = 1000.0 * (toc - tic)
print('naive loss: %e computed in %fs' % (loss_naive, ms_naive))

# Run and time the vectorized version
# YOUR_TURN: Complete the implementation of softmax_loss_vectorized
torch.cuda.synchronize()
tic = time.time()
loss_vec, grad_vec = softmax_loss_vectorized(W, X_batch, y_batch, reg)
torch.cuda.synchronize()
toc = time.time()
ms_vec = 1000.0 * (toc - tic)
print('vectorized loss: %e computed in %fs' % (loss_vec, ms_vec))

# we use the Frobenius norm to compare the two versions of the gradient.
loss_diff = (loss_naive - loss_vec).abs().item()
grad_diff = torch.norm(grad_naive - grad_vec, p='fro')
print('Loss difference: %.2e' % loss_diff)
print('Gradient difference: %.2e' % grad_diff)
print('Speedup: %.2fX' % (ms_naive / ms_vec))
# Out:
# naive loss: 2.302841e+00 computed in 202.993870s
# vectorized loss: 2.302841e+00 computed in 2.143145s
# Loss difference: 0.00e+00
# Gradient difference: 7.44e-16
# Speedup: 94.72X

# %% [markdown]
# Let's check that your implementation of the softmax loss is numerically stable.
#
# If either of the following print `nan` then you should double-check the numeric stability of your implementations.

# %%
import eecs598
from linear_classifier import softmax_loss_naive, softmax_loss_vectorized

eecs598.reset_seed(0)
device = data_dict['X_train'].device
dtype = data_dict['X_train'].dtype
D = data_dict['X_train'].shape[1]
C = 10

# YOUR_TURN??: train_linear_classifier should be same as what you've implemented in the SVM section
W_ones = torch.ones(D, C, device=device, dtype=dtype)
W, loss_hist = train_linear_classifier(softmax_loss_naive, W_ones, 
                                       data_dict['X_train'], 
                                       data_dict['y_train'], 
                                       learning_rate=1e-8, reg=2.5e4,
                                       num_iters=1, verbose=True)


W_ones = torch.ones(D, C, device=device, dtype=dtype)
W, loss_hist = train_linear_classifier(softmax_loss_vectorized, W_ones, 
                                       data_dict['X_train'], 
                                       data_dict['y_train'], 
                                       learning_rate=1e-8, reg=2.5e4,
                                       num_iters=1, verbose=True)
# Out:
# iteration 0 / 1: loss 768250002.302585
# iteration 0 / 1: loss 768250002.302585

# %% [markdown]
# Now lets train a softmax classifier with some default hyperparameters:

# %%
import eecs598
from linear_classifier import softmax_loss_vectorized

eecs598.reset_seed(0)

torch.cuda.synchronize()
tic = time.time()

# YOUR_TURN??: train_linear_classifier should be same as what you've implemented in the SVM section
W, loss_hist = train_linear_classifier(softmax_loss_vectorized, None, 
                                       data_dict['X_train'], 
                                       data_dict['y_train'], 
                                       learning_rate=1e-10, reg=2.5e4,
                                       num_iters=1500, verbose=True)

torch.cuda.synchronize()
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 2.303356
# iteration 100 / 1500: loss 2.303353
# iteration 200 / 1500: loss 2.303354
# iteration 300 / 1500: loss 2.303352
# iteration 400 / 1500: loss 2.303352
# iteration 500 / 1500: loss 2.303351
# iteration 600 / 1500: loss 2.303350
# iteration 700 / 1500: loss 2.303349
# iteration 800 / 1500: loss 2.303349
# iteration 900 / 1500: loss 2.303348
# iteration 1000 / 1500: loss 2.303347
# iteration 1100 / 1500: loss 2.303348
# iteration 1200 / 1500: loss 2.303347
# iteration 1300 / 1500: loss 2.303345
# iteration 1400 / 1500: loss 2.303345
# That took 2.194602s

# %% [markdown]
# Plot the loss curve:

# %%
plt.plot(loss_hist, 'o')
plt.xlabel('Iteration number')
plt.ylabel('Loss value')
plt.show()

# %% [markdown]
# Let's compute the accuracy of current model. It should be less than 10%.

# %%
import eecs598
from linear_classifier import predict_linear_classifier

eecs598.reset_seed(0)

# evaluate the performance on both the training and validation set
# YOUR_TURN??: predict_linear_classifier should be same as what you've implemented before, in the SVM section
y_train_pred = predict_linear_classifier(W, data_dict['X_train'])
train_acc = 100.0 * (data_dict['y_train'] == y_train_pred).double().mean().item()
print('training accuracy: %.2f%%' % train_acc)
y_val_pred = predict_linear_classifier(W, data_dict['X_val'])
val_acc = 100.0 * (data_dict['y_val'] == y_val_pred).double().mean().item()
print('validation accuracy: %.2f%%' % val_acc)
# Out:
# training accuracy: 8.90%
# validation accuracy: 8.54%

# %% [markdown]
# Now use the validation set to tune hyperparameters (regularization strength and learning rate). You should experiment with different ranges for the learning rates and regularization strengths.
#
# To get full credit for the assignment, your best model found through cross-validation should achieve an accuracy above 0.37 on the validation set.
#
# (Our best model was above 39.8% -- did you beat us?)

# %%
import os
import eecs598
from linear_classifier import Softmax, softmax_get_search_params, test_one_param_set

# YOUR_TURN: find the best learning_rates and regularization_strengths combination
#            in 'softmax_get_search_params'
learning_rates, regularization_strengths = softmax_get_search_params()
num_models = len(learning_rates) * len(regularization_strengths)

####
# It is okay to comment out the following conditions when you are working on svm_get_search_params.
# But, please do not forget to reset back to the original setting once you are done.
# if num_models > 25:
#   raise Exception("Please do not test/submit more than 25 items at once")
# elif num_models < 5:
#   raise Exception("Please present at least 5 parameter sets in your final ipynb")
####


i = 0
# As before, store your cross-validation results in this dictionary.
# The keys should be tuples of (learning_rate, regularization_strength) and
# the values should be tuples (train_acc, val_acc)
results = {}
best_val = -1.0   # The highest validation accuracy that we have seen so far.
best_softmax_model = None # The Softmax object that achieved the highest validation rate.
num_iters = 2000 # number of iterations

for lr in learning_rates:
  for reg in regularization_strengths:
    i += 1
    print('Training Softmax %d / %d with learning_rate=%e and reg=%e'
          % (i, num_models, lr, reg))
    
    eecs598.reset_seed(0)
    cand_softmax_model, cand_train_acc, cand_val_acc = test_one_param_set(Softmax(), data_dict, lr, reg, num_iters)

    if cand_val_acc > best_val:
      best_val = cand_val_acc
      best_softmax_model = cand_softmax_model # save the classifier
    results[(lr, reg)] = (cand_train_acc, cand_val_acc)


# Print out results.
for lr, reg in sorted(results):
  train_acc, val_acc = results[(lr, reg)]
  print('lr %e reg %e train accuracy: %f val accuracy: %f' % (
         lr, reg, train_acc, val_acc))
    
print('best validation accuracy achieved during cross-validation: %f' % best_val)

# save the best model
path = os.path.join(GOOGLE_DRIVE_PATH, 'softmax_best_model.pt')
best_softmax_model.save(path)
# Out:
# Training Softmax 1 / 240 with learning_rate=1.778279e-02 and reg=0.000000e+00
# Training Softmax 2 / 240 with learning_rate=1.778279e-02 and reg=1.000000e-15
# Training Softmax 3 / 240 with learning_rate=1.778279e-02 and reg=1.178769e-14
# Training Softmax 4 / 240 with learning_rate=1.778279e-02 and reg=1.389495e-13
# Training Softmax 5 / 240 with learning_rate=1.778279e-02 and reg=1.637894e-12
# Training Softmax 6 / 240 with learning_rate=1.778279e-02 and reg=1.930698e-11
# Training Softmax 7 / 240 with learning_rate=1.778279e-02 and reg=2.275846e-10
# Training Softmax 8 / 240 with learning_rate=1.778279e-02 and reg=2.682696e-09
# Training Softmax 9 / 240 with learning_rate=1.778279e-02 and reg=3.162278e-08
# Training Softmax 10 / 240 with learning_rate=1.778279e-02 and reg=3.727594e-07
# Training Softmax 11 / 240 with learning_rate=1.778279e-02 and reg=4.393970e-06
# Training Softmax 12 / 240 with learning_rate=1.778279e-02 and reg=5.179475e-05
# Training Softmax 13 / 240 with learning_rate=1.778279e-02 and reg=6.105402e-04
# Training Softmax 14 / 240 with learning_rate=1.778279e-02 and reg=7.196857e-03
# Training Softmax 15 / 240 with learning_rate=1.778279e-02 and reg=8.483429e-02
# Training Softmax 16 / 240 with learning_rate=1.778279e-02 and reg=1.000000e+00
# Training Softmax 17 / 240 with learning_rate=2.371374e-02 and reg=0.000000e+00
# Training Softmax 18 / 240 with learning_rate=2.371374e-02 and reg=1.000000e-15
# Training Softmax 19 / 240 with learning_rate=2.371374e-02 and reg=1.178769e-14
# Training Softmax 20 / 240 with learning_rate=2.371374e-02 and reg=1.389495e-13
# Training Softmax 21 / 240 with learning_rate=2.371374e-02 and reg=1.637894e-12
# Training Softmax 22 / 240 with learning_rate=2.371374e-02 and reg=1.930698e-11
# Training Softmax 23 / 240 with learning_rate=2.371374e-02 and reg=2.275846e-10
# Training Softmax 24 / 240 with learning_rate=2.371374e-02 and reg=2.682696e-09
# Training Softmax 25 / 240 with learning_rate=2.371374e-02 and reg=3.162278e-08
# Training Softmax 26 / 240 with learning_rate=2.371374e-02 and reg=3.727594e-07
# Training Softmax 27 / 240 with learning_rate=2.371374e-02 and reg=4.393970e-06
# Training Softmax 28 / 240 with learning_rate=2.371374e-02 and reg=5.179475e-05
# Training Softmax 29 / 240 with learning_rate=2.371374e-02 and reg=6.105402e-04
# Training Softmax 30 / 240 with learning_rate=2.371374e-02 and reg=7.196857e-03
# Training Softmax 31 / 240 with learning_rate=2.371374e-02 and reg=8.483429e-02
# Training Softmax 32 / 240 with learning_rate=2.371374e-02 and reg=1.000000e+00
# Training Softmax 33 / 240 with learning_rate=3.162277e-02 and reg=0.000000e+00
# Training Softmax 34 / 240 with learning_rate=3.162277e-02 and reg=1.000000e-15
# Training Softmax 35 / 240 with learning_rate=3.162277e-02 and reg=1.178769e-14
# Training Softmax 36 / 240 with learning_rate=3.162277e-02 and reg=1.389495e-13
# Training Softmax 37 / 240 with learning_rate=3.162277e-02 and reg=1.637894e-12
# Training Softmax 38 / 240 with learning_rate=3.162277e-02 and reg=1.930698e-11
# Training Softmax 39 / 240 with learning_rate=3.162277e-02 and reg=2.275846e-10
# Training Softmax 40 / 240 with learning_rate=3.162277e-02 and reg=2.682696e-09
# Training Softmax 41 / 240 with learning_rate=3.162277e-02 and reg=3.162278e-08
# Training Softmax 42 / 240 with learning_rate=3.162277e-02 and reg=3.727594e-07
# Training Softmax 43 / 240 with learning_rate=3.162277e-02 and reg=4.393970e-06
# Training Softmax 44 / 240 with learning_rate=3.162277e-02 and reg=5.179475e-05
# Training Softmax 45 / 240 with learning_rate=3.162277e-02 and reg=6.105402e-04
# Training Softmax 46 / 240 with learning_rate=3.162277e-02 and reg=7.196857e-03
# Training Softmax 47 / 240 with learning_rate=3.162277e-02 and reg=8.483429e-02
# Training Softmax 48 / 240 with learning_rate=3.162277e-02 and reg=1.000000e+00
# Training Softmax 49 / 240 with learning_rate=4.216965e-02 and reg=0.000000e+00
# Training Softmax 50 / 240 with learning_rate=4.216965e-02 and reg=1.000000e-15
# Training Softmax 51 / 240 with learning_rate=4.216965e-02 and reg=1.178769e-14
# Training Softmax 52 / 240 with learning_rate=4.216965e-02 and reg=1.389495e-13
# Training Softmax 53 / 240 with learning_rate=4.216965e-02 and reg=1.637894e-12
# Training Softmax 54 / 240 with learning_rate=4.216965e-02 and reg=1.930698e-11
# Training Softmax 55 / 240 with learning_rate=4.216965e-02 and reg=2.275846e-10
# Training Softmax 56 / 240 with learning_rate=4.216965e-02 and reg=2.682696e-09
# Training Softmax 57 / 240 with learning_rate=4.216965e-02 and reg=3.162278e-08
# Training Softmax 58 / 240 with learning_rate=4.216965e-02 and reg=3.727594e-07
# Training Softmax 59 / 240 with learning_rate=4.216965e-02 and reg=4.393970e-06
# Training Softmax 60 / 240 with learning_rate=4.216965e-02 and reg=5.179475e-05
# Training Softmax 61 / 240 with learning_rate=4.216965e-02 and reg=6.105402e-04
# Training Softmax 62 / 240 with learning_rate=4.216965e-02 and reg=7.196857e-03
# Training Softmax 63 / 240 with learning_rate=4.216965e-02 and reg=8.483429e-02
# Training Softmax 64 / 240 with learning_rate=4.216965e-02 and reg=1.000000e+00
# Training Softmax 65 / 240 with learning_rate=5.623413e-02 and reg=0.000000e+00
# Training Softmax 66 / 240 with learning_rate=5.623413e-02 and reg=1.000000e-15
# Training Softmax 67 / 240 with learning_rate=5.623413e-02 and reg=1.178769e-14
# Training Softmax 68 / 240 with learning_rate=5.623413e-02 and reg=1.389495e-13
# Training Softmax 69 / 240 with learning_rate=5.623413e-02 and reg=1.637894e-12
# Training Softmax 70 / 240 with learning_rate=5.623413e-02 and reg=1.930698e-11
# Training Softmax 71 / 240 with learning_rate=5.623413e-02 and reg=2.275846e-10
# Training Softmax 72 / 240 with learning_rate=5.623413e-02 and reg=2.682696e-09
# Training Softmax 73 / 240 with learning_rate=5.623413e-02 and reg=3.162278e-08
# Training Softmax 74 / 240 with learning_rate=5.623413e-02 and reg=3.727594e-07
# Training Softmax 75 / 240 with learning_rate=5.623413e-02 and reg=4.393970e-06
# Training Softmax 76 / 240 with learning_rate=5.623413e-02 and reg=5.179475e-05
# Training Softmax 77 / 240 with learning_rate=5.623413e-02 and reg=6.105402e-04
# Training Softmax 78 / 240 with learning_rate=5.623413e-02 and reg=7.196857e-03
# Training Softmax 79 / 240 with learning_rate=5.623413e-02 and reg=8.483429e-02
# Training Softmax 80 / 240 with learning_rate=5.623413e-02 and reg=1.000000e+00
# Training Softmax 81 / 240 with learning_rate=7.498942e-02 and reg=0.000000e+00
# Training Softmax 82 / 240 with learning_rate=7.498942e-02 and reg=1.000000e-15
# Training Softmax 83 / 240 with learning_rate=7.498942e-02 and reg=1.178769e-14
# Training Softmax 84 / 240 with learning_rate=7.498942e-02 and reg=1.389495e-13
# Training Softmax 85 / 240 with learning_rate=7.498942e-02 and reg=1.637894e-12
# Training Softmax 86 / 240 with learning_rate=7.498942e-02 and reg=1.930698e-11
# Training Softmax 87 / 240 with learning_rate=7.498942e-02 and reg=2.275846e-10
# Training Softmax 88 / 240 with learning_rate=7.498942e-02 and reg=2.682696e-09
# Training Softmax 89 / 240 with learning_rate=7.498942e-02 and reg=3.162278e-08
# Training Softmax 90 / 240 with learning_rate=7.498942e-02 and reg=3.727594e-07
# Training Softmax 91 / 240 with learning_rate=7.498942e-02 and reg=4.393970e-06
# Training Softmax 92 / 240 with learning_rate=7.498942e-02 and reg=5.179475e-05
# Training Softmax 93 / 240 with learning_rate=7.498942e-02 and reg=6.105402e-04
# Training Softmax 94 / 240 with learning_rate=7.498942e-02 and reg=7.196857e-03
# Training Softmax 95 / 240 with learning_rate=7.498942e-02 and reg=8.483429e-02
# Training Softmax 96 / 240 with learning_rate=7.498942e-02 and reg=1.000000e+00
# Training Softmax 97 / 240 with learning_rate=1.000000e-01 and reg=0.000000e+00
# Training Softmax 98 / 240 with learning_rate=1.000000e-01 and reg=1.000000e-15
# Training Softmax 99 / 240 with learning_rate=1.000000e-01 and reg=1.178769e-14
# Training Softmax 100 / 240 with learning_rate=1.000000e-01 and reg=1.389495e-13
# Training Softmax 101 / 240 with learning_rate=1.000000e-01 and reg=1.637894e-12
# Training Softmax 102 / 240 with learning_rate=1.000000e-01 and reg=1.930698e-11
# Training Softmax 103 / 240 with learning_rate=1.000000e-01 and reg=2.275846e-10
# Training Softmax 104 / 240 with learning_rate=1.000000e-01 and reg=2.682696e-09
# Training Softmax 105 / 240 with learning_rate=1.000000e-01 and reg=3.162278e-08
# Training Softmax 106 / 240 with learning_rate=1.000000e-01 and reg=3.727594e-07
# Training Softmax 107 / 240 with learning_rate=1.000000e-01 and reg=4.393970e-06
# Training Softmax 108 / 240 with learning_rate=1.000000e-01 and reg=5.179475e-05
# Training Softmax 109 / 240 with learning_rate=1.000000e-01 and reg=6.105402e-04
# Training Softmax 110 / 240 with learning_rate=1.000000e-01 and reg=7.196857e-03
# Training Softmax 111 / 240 with learning_rate=1.000000e-01 and reg=8.483429e-02
# Training Softmax 112 / 240 with learning_rate=1.000000e-01 and reg=1.000000e+00
# Training Softmax 113 / 240 with learning_rate=1.333521e-01 and reg=0.000000e+00
# Training Softmax 114 / 240 with learning_rate=1.333521e-01 and reg=1.000000e-15
# Training Softmax 115 / 240 with learning_rate=1.333521e-01 and reg=1.178769e-14
# Training Softmax 116 / 240 with learning_rate=1.333521e-01 and reg=1.389495e-13
# Training Softmax 117 / 240 with learning_rate=1.333521e-01 and reg=1.637894e-12
# Training Softmax 118 / 240 with learning_rate=1.333521e-01 and reg=1.930698e-11
# Training Softmax 119 / 240 with learning_rate=1.333521e-01 and reg=2.275846e-10
# Training Softmax 120 / 240 with learning_rate=1.333521e-01 and reg=2.682696e-09
# Training Softmax 121 / 240 with learning_rate=1.333521e-01 and reg=3.162278e-08
# Training Softmax 122 / 240 with learning_rate=1.333521e-01 and reg=3.727594e-07
# Training Softmax 123 / 240 with learning_rate=1.333521e-01 and reg=4.393970e-06
# Training Softmax 124 / 240 with learning_rate=1.333521e-01 and reg=5.179475e-05
# Training Softmax 125 / 240 with learning_rate=1.333521e-01 and reg=6.105402e-04
# Training Softmax 126 / 240 with learning_rate=1.333521e-01 and reg=7.196857e-03
# Training Softmax 127 / 240 with learning_rate=1.333521e-01 and reg=8.483429e-02
# Training Softmax 128 / 240 with learning_rate=1.333521e-01 and reg=1.000000e+00
# Training Softmax 129 / 240 with learning_rate=1.778279e-01 and reg=0.000000e+00
# Training Softmax 130 / 240 with learning_rate=1.778279e-01 and reg=1.000000e-15
# Training Softmax 131 / 240 with learning_rate=1.778279e-01 and reg=1.178769e-14
# Training Softmax 132 / 240 with learning_rate=1.778279e-01 and reg=1.389495e-13
# Training Softmax 133 / 240 with learning_rate=1.778279e-01 and reg=1.637894e-12
# Training Softmax 134 / 240 with learning_rate=1.778279e-01 and reg=1.930698e-11
# Training Softmax 135 / 240 with learning_rate=1.778279e-01 and reg=2.275846e-10
# Training Softmax 136 / 240 with learning_rate=1.778279e-01 and reg=2.682696e-09
# Training Softmax 137 / 240 with learning_rate=1.778279e-01 and reg=3.162278e-08
# Training Softmax 138 / 240 with learning_rate=1.778279e-01 and reg=3.727594e-07
# Training Softmax 139 / 240 with learning_rate=1.778279e-01 and reg=4.393970e-06
# Training Softmax 140 / 240 with learning_rate=1.778279e-01 and reg=5.179475e-05
# Training Softmax 141 / 240 with learning_rate=1.778279e-01 and reg=6.105402e-04
# Training Softmax 142 / 240 with learning_rate=1.778279e-01 and reg=7.196857e-03
# Training Softmax 143 / 240 with learning_rate=1.778279e-01 and reg=8.483429e-02
# Training Softmax 144 / 240 with learning_rate=1.778279e-01 and reg=1.000000e+00
# Training Softmax 145 / 240 with learning_rate=2.371374e-01 and reg=0.000000e+00
# Training Softmax 146 / 240 with learning_rate=2.371374e-01 and reg=1.000000e-15
# Training Softmax 147 / 240 with learning_rate=2.371374e-01 and reg=1.178769e-14
# Training Softmax 148 / 240 with learning_rate=2.371374e-01 and reg=1.389495e-13
# Training Softmax 149 / 240 with learning_rate=2.371374e-01 and reg=1.637894e-12
# Training Softmax 150 / 240 with learning_rate=2.371374e-01 and reg=1.930698e-11
# Training Softmax 151 / 240 with learning_rate=2.371374e-01 and reg=2.275846e-10
# Training Softmax 152 / 240 with learning_rate=2.371374e-01 and reg=2.682696e-09
# Training Softmax 153 / 240 with learning_rate=2.371374e-01 and reg=3.162278e-08
# Training Softmax 154 / 240 with learning_rate=2.371374e-01 and reg=3.727594e-07
# Training Softmax 155 / 240 with learning_rate=2.371374e-01 and reg=4.393970e-06
# Training Softmax 156 / 240 with learning_rate=2.371374e-01 and reg=5.179475e-05
# Training Softmax 157 / 240 with learning_rate=2.371374e-01 and reg=6.105402e-04
# Training Softmax 158 / 240 with learning_rate=2.371374e-01 and reg=7.196857e-03
# Training Softmax 159 / 240 with learning_rate=2.371374e-01 and reg=8.483429e-02
# Training Softmax 160 / 240 with learning_rate=2.371374e-01 and reg=1.000000e+00
# Training Softmax 161 / 240 with learning_rate=3.162278e-01 and reg=0.000000e+00
# Training Softmax 162 / 240 with learning_rate=3.162278e-01 and reg=1.000000e-15
# Training Softmax 163 / 240 with learning_rate=3.162278e-01 and reg=1.178769e-14
# Training Softmax 164 / 240 with learning_rate=3.162278e-01 and reg=1.389495e-13
# Training Softmax 165 / 240 with learning_rate=3.162278e-01 and reg=1.637894e-12
# Training Softmax 166 / 240 with learning_rate=3.162278e-01 and reg=1.930698e-11
# Training Softmax 167 / 240 with learning_rate=3.162278e-01 and reg=2.275846e-10
# Training Softmax 168 / 240 with learning_rate=3.162278e-01 and reg=2.682696e-09
# Training Softmax 169 / 240 with learning_rate=3.162278e-01 and reg=3.162278e-08
# Training Softmax 170 / 240 with learning_rate=3.162278e-01 and reg=3.727594e-07
# Training Softmax 171 / 240 with learning_rate=3.162278e-01 and reg=4.393970e-06
# Training Softmax 172 / 240 with learning_rate=3.162278e-01 and reg=5.179475e-05
# Training Softmax 173 / 240 with learning_rate=3.162278e-01 and reg=6.105402e-04
# Training Softmax 174 / 240 with learning_rate=3.162278e-01 and reg=7.196857e-03
# Training Softmax 175 / 240 with learning_rate=3.162278e-01 and reg=8.483429e-02
# Training Softmax 176 / 240 with learning_rate=3.162278e-01 and reg=1.000000e+00
# Training Softmax 177 / 240 with learning_rate=4.216965e-01 and reg=0.000000e+00
# Training Softmax 178 / 240 with learning_rate=4.216965e-01 and reg=1.000000e-15
# Training Softmax 179 / 240 with learning_rate=4.216965e-01 and reg=1.178769e-14
# Training Softmax 180 / 240 with learning_rate=4.216965e-01 and reg=1.389495e-13
# Training Softmax 181 / 240 with learning_rate=4.216965e-01 and reg=1.637894e-12
# Training Softmax 182 / 240 with learning_rate=4.216965e-01 and reg=1.930698e-11
# Training Softmax 183 / 240 with learning_rate=4.216965e-01 and reg=2.275846e-10
# Training Softmax 184 / 240 with learning_rate=4.216965e-01 and reg=2.682696e-09
# Training Softmax 185 / 240 with learning_rate=4.216965e-01 and reg=3.162278e-08
# Training Softmax 186 / 240 with learning_rate=4.216965e-01 and reg=3.727594e-07
# Training Softmax 187 / 240 with learning_rate=4.216965e-01 and reg=4.393970e-06
# Training Softmax 188 / 240 with learning_rate=4.216965e-01 and reg=5.179475e-05
# Training Softmax 189 / 240 with learning_rate=4.216965e-01 and reg=6.105402e-04
# Training Softmax 190 / 240 with learning_rate=4.216965e-01 and reg=7.196857e-03
# Training Softmax 191 / 240 with learning_rate=4.216965e-01 and reg=8.483429e-02
# Training Softmax 192 / 240 with learning_rate=4.216965e-01 and reg=1.000000e+00
# Training Softmax 193 / 240 with learning_rate=5.623413e-01 and reg=0.000000e+00
# Training Softmax 194 / 240 with learning_rate=5.623413e-01 and reg=1.000000e-15
# Training Softmax 195 / 240 with learning_rate=5.623413e-01 and reg=1.178769e-14
# Training Softmax 196 / 240 with learning_rate=5.623413e-01 and reg=1.389495e-13
# Training Softmax 197 / 240 with learning_rate=5.623413e-01 and reg=1.637894e-12
# Training Softmax 198 / 240 with learning_rate=5.623413e-01 and reg=1.930698e-11
# Training Softmax 199 / 240 with learning_rate=5.623413e-01 and reg=2.275846e-10
# Training Softmax 200 / 240 with learning_rate=5.623413e-01 and reg=2.682696e-09
# Training Softmax 201 / 240 with learning_rate=5.623413e-01 and reg=3.162278e-08
# Training Softmax 202 / 240 with learning_rate=5.623413e-01 and reg=3.727594e-07
# Training Softmax 203 / 240 with learning_rate=5.623413e-01 and reg=4.393970e-06
# Training Softmax 204 / 240 with learning_rate=5.623413e-01 and reg=5.179475e-05
# Training Softmax 205 / 240 with learning_rate=5.623413e-01 and reg=6.105402e-04
# Training Softmax 206 / 240 with learning_rate=5.623413e-01 and reg=7.196857e-03
# Training Softmax 207 / 240 with learning_rate=5.623413e-01 and reg=8.483429e-02
# Training Softmax 208 / 240 with learning_rate=5.623413e-01 and reg=1.000000e+00
# Training Softmax 209 / 240 with learning_rate=7.498942e-01 and reg=0.000000e+00
# Training Softmax 210 / 240 with learning_rate=7.498942e-01 and reg=1.000000e-15
# Training Softmax 211 / 240 with learning_rate=7.498942e-01 and reg=1.178769e-14
# Training Softmax 212 / 240 with learning_rate=7.498942e-01 and reg=1.389495e-13
# Training Softmax 213 / 240 with learning_rate=7.498942e-01 and reg=1.637894e-12
# Training Softmax 214 / 240 with learning_rate=7.498942e-01 and reg=1.930698e-11
# Training Softmax 215 / 240 with learning_rate=7.498942e-01 and reg=2.275846e-10
# Training Softmax 216 / 240 with learning_rate=7.498942e-01 and reg=2.682696e-09
# Training Softmax 217 / 240 with learning_rate=7.498942e-01 and reg=3.162278e-08
# Training Softmax 218 / 240 with learning_rate=7.498942e-01 and reg=3.727594e-07
# Training Softmax 219 / 240 with learning_rate=7.498942e-01 and reg=4.393970e-06
# Training Softmax 220 / 240 with learning_rate=7.498942e-01 and reg=5.179475e-05
# Training Softmax 221 / 240 with learning_rate=7.498942e-01 and reg=6.105402e-04
# Training Softmax 222 / 240 with learning_rate=7.498942e-01 and reg=7.196857e-03
# Training Softmax 223 / 240 with learning_rate=7.498942e-01 and reg=8.483429e-02
# Training Softmax 224 / 240 with learning_rate=7.498942e-01 and reg=1.000000e+00
# Training Softmax 225 / 240 with learning_rate=1.000000e+00 and reg=0.000000e+00
# Training Softmax 226 / 240 with learning_rate=1.000000e+00 and reg=1.000000e-15
# Training Softmax 227 / 240 with learning_rate=1.000000e+00 and reg=1.178769e-14
# Training Softmax 228 / 240 with learning_rate=1.000000e+00 and reg=1.389495e-13
# Training Softmax 229 / 240 with learning_rate=1.000000e+00 and reg=1.637894e-12
# Training Softmax 230 / 240 with learning_rate=1.000000e+00 and reg=1.930698e-11
# Training Softmax 231 / 240 with learning_rate=1.000000e+00 and reg=2.275846e-10
# Training Softmax 232 / 240 with learning_rate=1.000000e+00 and reg=2.682696e-09
# Training Softmax 233 / 240 with learning_rate=1.000000e+00 and reg=3.162278e-08
# Training Softmax 234 / 240 with learning_rate=1.000000e+00 and reg=3.727594e-07
# Training Softmax 235 / 240 with learning_rate=1.000000e+00 and reg=4.393970e-06
# Training Softmax 236 / 240 with learning_rate=1.000000e+00 and reg=5.179475e-05
# Training Softmax 237 / 240 with learning_rate=1.000000e+00 and reg=6.105402e-04
# Training Softmax 238 / 240 with learning_rate=1.000000e+00 and reg=7.196857e-03
# Training Softmax 239 / 240 with learning_rate=1.000000e+00 and reg=8.483429e-02
# Training Softmax 240 / 240 with learning_rate=1.000000e+00 and reg=1.000000e+00
# lr 1.778279e-02 reg 0.000000e+00 train accuracy: 41.585000 val accuracy: 39.830000
# lr 1.778279e-02 reg
# lr 7.498942e-01 reg 1.000000e-15 train accuracy: 38.255000 val accuracy: 34.110000
# lr 7.498942e-01 reg 1.178769e-14 train accuracy: 36.972500 val accuracy: 32.350000
# lr 7.498942e-01 reg 1.389495e-13 train accuracy: 37.705000 val accuracy: 34.010000
# lr 7.498942e-01 reg 1.637894e-12 train accuracy: 36.782500 val accuracy: 33.340000
# lr 7.498942e-01 reg 1.930698e-11 train accuracy: 37.635000 val accuracy: 33.180000
# lr 7.498942e-01 reg 2.275846e-10 train accuracy: 34.750000 val accuracy: 30.290000
# lr 7.498942e-01 reg 2.682696e-09 train accuracy: 36.667500 val accuracy: 32.900000
# lr 7.498942e-01 reg 3.162278e-08 train accuracy: 38.375000 val accuracy: 34.210000
# lr 7.498942e-01 reg 3.727594e-07 train accuracy: 36.717500 val accuracy: 32.900000
# lr 7.498942e-01 reg 4.393970e-06 train accuracy: 35.197500 val accuracy: 30.860000
# lr 7.498942e-01 reg 5.179475e-05 train accuracy: 36.750000 val accuracy: 32.560000
# lr 7.498942e-01 reg 6.105402e-04 train accuracy: 34.252500 val accuracy: 31.670000
# lr 7.498942e-01 reg 7.196857e-03 train accuracy: 30.950000 val accuracy: 30.510000
# lr 7.498942e-01 reg 8.483429e-02 train accuracy: 17.495000 val accuracy: 17.500000
# lr 7.498942e-01 reg 1.000000e+00 train accuracy: 5.925000 val accuracy: 5.920000
# lr 1.000000e+00 reg 0.000000e+00 train accuracy: 35.467500 val accuracy: 32.010000
# lr 1.000000e+00 reg 1.000000e-15 train accuracy: 32.860000 val accuracy: 28.510000
# lr 1.000000e+00 reg 1.178769e-14 train accuracy: 36.530000 val accuracy: 33.020000
# lr 1.000000e+00 reg 1.389495e-13 train accuracy: 38.247500 val accuracy: 33.220000
# lr 1.000000e+00 reg 1.637894e-12 train accuracy: 37.552500 val accuracy: 33.310000
# lr 1.000000e+00 reg 1.930698e-11 train accuracy: 35.600000 val accuracy: 32.230000
# lr 1.000000e+00 reg 2.275846e-10 train accuracy: 35.985000 val accuracy: 32.330000
# lr 1.000000e+00 reg 2.682696e-09 train accuracy: 33.282500 val accuracy: 29.900000
# lr 1.000000e+00 reg 3.162278e-08 train accuracy: 38.075000 val accuracy: 33.780000
# lr 1.000000e+00 reg 3.727594e-07 train accuracy: 33.370000 val accuracy: 30.220000
# lr 1.000000e+00 reg 4.393970e-06 train accuracy: 38.252500 val accuracy: 33.830000
# lr 1.000000e+00 reg 5.179475e-05 train accuracy: 36.177500 val accuracy: 32.220000
# lr 1.000000e+00 reg 6.105402e-04 train accuracy: 32.555000 val accuracy: 30.510000
# lr 1.000000e+00 reg 7.196857e-03 train accuracy: 29.467500 val accuracy: 28.640000
# lr 1.000000e+00 reg 8.483429e-02 train accuracy: 18.312500 val accuracy: 18.430000
# lr 1.000000e+00 reg 1.000000e+00 train accuracy: 5.245000 val accuracy: 5.180000
# best validation accuracy achieved during cross-validation: 40.560000
# Saved in c:\Users\houghj\Downloads\A2\A2\softmax_best_model.pt

# %% [markdown]
# Run the following to visualize your cross-validation results:

# %%
x_scatter = [math.log10(x[0]+1e-9) for x in results]
y_scatter = [math.log10(x[1]+1e-9) for x in results]

# plot training accuracy
marker_size = 100
colors = [results[x][0] for x in results]
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 training accuracy')
plt.gcf().set_size_inches(8, 5)
plt.show()

# plot validation accuracy
colors = [results[x][1] for x in results] # default size of markers is 20
plt.scatter(x_scatter, y_scatter, marker_size, c=colors, cmap='viridis')
plt.colorbar()
plt.xlabel('log learning rate')
plt.ylabel('log regularization strength')
plt.title('CIFAR-10 validation accuracy')
plt.gcf().set_size_inches(8, 5)
plt.show()

# %% [markdown]
# Them, evaluate the performance of your best model on test set. To get full credit for this assignment you should achieve a test-set accuracy above 0.36.
#
# (Our best was just around 39.9% -- did you beat us?)

# %%
y_test_pred = best_softmax_model.predict(data_dict['X_test'])
test_accuracy = torch.mean((data_dict['y_test'] == y_test_pred).double())
print('softmax on raw pixels final test set accuracy: %f' % (test_accuracy, ))
# Out:
# softmax on raw pixels final test set accuracy: 0.404300

# %% [markdown]
# Finally, let's visualize the learned weights for each class

# %%
w = best_softmax_model.W[:-1,:] # strip out the bias
w = w.reshape(3, 32, 32, 10)
w = w.transpose(0, 2).transpose(1, 0)

w_min, w_max = torch.min(w), torch.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in range(10):
  plt.subplot(2, 5, i + 1)

  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.type(torch.uint8).cpu())
  plt.axis('off')
  plt.title(classes[i])
